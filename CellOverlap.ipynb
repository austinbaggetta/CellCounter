# %% [markdown]
# ### Calculate overlapping cells between multiple cell markers.

# %%
import os
import cv2
import pandas as pd
import numpy as np
import xarray as xr
import json 
from os.path import join as pjoin
import plotly.express as px

# %%
## Settings
